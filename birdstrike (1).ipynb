# %% [markdown]
# ### Bird Strike Analysis

# %%
import pandas as pd
import numpy as np

# %%
birdstrike = pd.read_csv('/content/Bird Strikes data.xlsx - Bird Strikes.csv')
birdstrike.head()
# Out:
#    Record ID Aircraft: Type                Airport: Name Altitude bin  \
# 0     202152       Airplane                 LAGUARDIA NY    > 1000 ft
# 1     208159       Airplane  DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2     207601       Airplane            LAKEFRONT AIRPORT    < 1000 ft
# 3     215953       Airplane          SEATTLE-TACOMA INTL    < 1000 ft
# 4     219878       Airplane                 NORFOLK INTL    < 1000 ft
#
#   Aircraft: Make/Model Wildlife: Number struck  \
# 0            B-737-400                Over 100
# 1                MD-80                Over 100
# 2                C-500                Over 100
# 3            B-737-400                Over 100
# 4         CL-RJ100/200                Over 100
#
#    Wildlife: Number Struck Actual Effect: Impact to flight     FlightDate  \
# 0                             859         Engine Shut Down  11/23/00 0:00
# 1                             424                      NaN   7/25/01 0:00
# ...

# %%
birdstrike.shape
# Out:
# (25558, 26)

# %%
birdstrike.describe()
# Out:
#            Record ID  Wildlife: Number Struck Actual  Number of people injured
# count   25558.000000                    25558.000000              25558.000000
# mean   253916.085609                        2.691525                  0.001056
# std     38510.453382                       12.793975                  0.050420
# min      1195.000000                        1.000000                  0.000000
# 25%    225783.750000                        1.000000                  0.000000
# 50%    248749.000000                        1.000000                  0.000000
# 75%    269168.750000                        1.000000                  0.000000
# max    321909.000000                      942.000000                  6.000000

# %%
birdstrike.isnull().sum()
# Out:
# Record ID                                      0
# Aircraft: Type                               129
# Airport: Name                                129
# Altitude bin                                 129
# Aircraft: Make/Model                           0
# Wildlife: Number struck                      129
# Wildlife: Number Struck Actual                 0
# Effect: Impact to flight                   23480
# FlightDate                                   129
# Effect: Indicated Damage                       0
# Aircraft: Number of engines?                 267
# Aircraft: Airline/Operator                   129
# Origin State                                 449
# When: Phase of flight                        129
# Conditions: Precipitation                  23543
# Remains of wildlife collected?                 0
# Remains of wildlife sent to Smithsonian        0
# Remarks                                     4771
# Wildlife: Size                               129
# ...

# %%
# Fill missing values in 'Effect: Impact to flight' and 'Conditions: Precipitation' with a placeholder
# Fill missing values in 'Effect: Impact to flight' and 'Conditions: Precipitation' with a placeholder
birdstrike['Effect: Impact to flight'].fillna('No effect', inplace=True)
birdstrike['Conditions: Precipitation'].fillna('no condition', inplace=True)

# %%
birdstrike.dropna(subset=["Airport: Name","Effect: Impact to flight","FlightDate","Aircraft: Number of engines?","Aircraft: Airline/Operator","Origin State","When: Phase of flight","Conditions: Precipitation","Wildlife: Size","Pilot warned of birds or wildlife?","Feet above ground","Is Aircraft Large?"],inplace= True)

# %%
birdstrike.isnull().sum()
# Out:
# Record ID                                     0
# Aircraft: Type                                0
# Airport: Name                                 0
# Altitude bin                                  0
# Aircraft: Make/Model                          0
# Wildlife: Number struck                       0
# Wildlife: Number Struck Actual                0
# Effect: Impact to flight                      0
# FlightDate                                    0
# Effect: Indicated Damage                      0
# Aircraft: Number of engines?                  0
# Aircraft: Airline/Operator                    0
# Origin State                                  0
# When: Phase of flight                         0
# Conditions: Precipitation                     0
# Remains of wildlife collected?                0
# Remains of wildlife sent to Smithsonian       0
# Remarks                                    4605
# Wildlife: Size                                0
# Conditions: Sky                               0
# ...

# %%
birdstrike.drop('Remarks', axis=1, inplace=True)

# %%
birdstrike.shape
# Out:
# (24747, 25)

# %%
birdstrike.isnull().sum()
# Out:
# Record ID                                  0
# Aircraft: Type                             0
# Airport: Name                              0
# Altitude bin                               0
# Aircraft: Make/Model                       0
# Wildlife: Number struck                    0
# Wildlife: Number Struck Actual             0
# Effect: Impact to flight                   0
# FlightDate                                 0
# Effect: Indicated Damage                   0
# Aircraft: Number of engines?               0
# Aircraft: Airline/Operator                 0
# Origin State                               0
# When: Phase of flight                      0
# Conditions: Precipitation                  0
# Remains of wildlife collected?             0
# Remains of wildlife sent to Smithsonian    0
# Wildlife: Size                             0
# Conditions: Sky                            0
# Wildlife: Species                          0
# Pilot warned of birds or wildlife?         0
# ...

# %%
birdstrike.shape
# Out:
# (24747, 25)

# %%
birdstrike.to_csv("correctbirdstrike.csv",index=False)
